# %% [markdown]
# <a href="https://colab.research.google.com/github/matstabel/data-science-project/blob/main/ML_Exercise6_solution_V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning for BI 2
#
# ## Deep Learning exercises for week 5
#
# In this exercise, you'll expand on last weeks exercise by adding pre-trained models to the mix. In particular, you'll work with ResNet50, a powerful pre-trained model.

# %% [markdown]
# Here is the task: Try a ResNet50 with data augmentation on the cifar10 dataset.
#
# Two tips:
#
#
#
# 1.   Remember to turn on the GPU. Don't let it stand idle. Whenever you need to take a break, remember to switch it off.
# 2.   When preprocessing the model, do this to avoid errors
#
# ```
# # Apply the preprocess_input function
# x = Lambda(preprocess_input)(x)
# ```
#
# This allows arbitrary expressions to be inserted into Keras models.

# %% [markdown]
# ## Using a pre-trained ResNet50 model
#
# **Load libraries**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input, Lambda, Layer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.applications.resnet50 import preprocess_input

# %% [markdown]
# **Load data**

# %%
# Load CIFAR-10 data
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %% [markdown]
# **Model building**

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
])

# %%
# Make sure you define the 'base_model' after the augmentation and normalization
# Ensure the 'input_tensor' argument in ResNet50 is replaced with 'input_shape'
# if you are defining 'x' as the output of previous layers
base_model = keras.applications.ResNet50(include_top=False,
                                         weights='imagenet',
                                         input_shape=(32, 32, 3))
base_model.trainable = False

# Define the input tensor for your model
input_tensor = Input(shape=(32, 32, 3))

# Apply data augmentation to the inputs
x = data_augmentation(input_tensor)

# Apply the preprocess_input function
x = Lambda(preprocess_input)(x)

# Add custom layers on top of the base model
x = base_model(x)
x = GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
predictions = Dense(10, activation='softmax')(x)

# Create the final model
model = Model(inputs=input_tensor, outputs=predictions)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# **Compile**

# %%
model.compile(optimizer="Adam", loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# **Train**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="resnet50.keras",
        save_best_only=True,
        monitor="val_loss")
]

# %%
history = model.fit(x_train, y_train,
                    epochs=40,
                    batch_size=256,
                    validation_split=0.2,  # Use 20% of the data for validation
                    callbacks=callbacks,  # Include the callbacks in training
                    verbose=1)
# Out:
# Epoch 1/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 22s 67ms/step - accuracy: 0.4165 - loss: 1.8385 - val_accuracy: 0.5916 - val_loss: 1.1777
# Epoch 2/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - accuracy: 0.4994 - loss: 1.4281 - val_accuracy: 0.6142 - val_loss: 1.1107
# Epoch 3/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - accuracy: 0.5215 - loss: 1.3551 - val_accuracy: 0.6211 - val_loss: 1.0829
# Epoch 4/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - accuracy: 0.5419 - loss: 1.3099 - val_accuracy: 0.6218 - val_loss: 1.0794
# Epoch 5/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.5483 - loss: 1.2807 - val_accuracy: 0.6363 - val_loss: 1.0494
# Epoch 6/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - accuracy: 0.5604 - loss: 1.2547 - val_accuracy: 0.6428 - val_loss: 1.0370
# Epoch 7/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - accuracy: 0.5641 - loss: 1.2350 - val_accuracy: 0.6432 - val_loss: 1.0308
# Epoch 8/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.5696 - loss: 1.2282 - val_accuracy: 0.6467 - val_loss: 1.0091
# Epoch 9/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - accuracy: 0.5729 - loss: 1.2083 - val_accuracy: 0.6599 - val_loss: 0.9909
# Epoch 10/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - accuracy: 0.5780 - loss: 1.1950 - val_accuracy: 0.6489 - val_loss: 1.0052
# Epoch 11/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.5811 - loss: 1.1825 - val_accuracy: 0.6558 - val_loss: 0.9835
# Epoch 12/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - accuracy: 0.5838 - loss: 1.1775 - val_accuracy: 0.6543 - val_loss: 0.9796
# Epoch 13/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.5892 - loss: 1.1655 - val_accuracy: 0.6550 - val_loss: 0.9804
# Epoch 14/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - accuracy: 0.5966 - loss: 1.1532 - val_accuracy: 0.6523 - val_loss: 0.9781
# Epoch 15/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - accuracy: 0.5979 - loss: 1.1455 - val_accuracy: 0.6580 - val_loss: 0.9778
# Epoch 16/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - accuracy: 0.5985 - loss: 1.1409 - val_accuracy: 0.6621 - val_loss: 0.9712
# Epoch 17/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.6008 - loss: 1.1353 - val_accuracy: 0.6605 - val_loss: 0.9681
# Epoch 18/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6025 - loss: 1.1340 - val_accuracy: 0.6589 - val_loss: 0.9743
# Epoch 19/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - accuracy: 0.6055 - loss: 1.1238 - val_accuracy: 0.6648 - val_loss: 0.9623
# Epoch 20/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6082 - loss: 1.1229 - val_accuracy: 0.6626 - val_loss: 0.9678
# Epoch 21/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.6071 - loss: 1.1106 - val_accuracy: 0.6657 - val_loss: 0.9710
# Epoch 22/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - accuracy: 0.6091 - loss: 1.1112 - val_accuracy: 0.6629 - val_loss: 0.9588
# Epoch 23/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - accuracy: 0.6086 - loss: 1.1159 - val_accuracy: 0.6663 - val_loss: 0.9561
# Epoch 24/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - accuracy: 0.6102 - loss: 1.1013 - val_accuracy: 0.6658 - val_loss: 0.9528
# Epoch 25/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.6108 - loss: 1.1040 - val_accuracy: 0.6641 - val_loss: 0.9612
# Epoch 26/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.6112 - loss: 1.1081 - val_accuracy: 0.6703 - val_loss: 0.9569
# Epoch 27/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - accuracy: 0.6151 - loss: 1.0966 - val_accuracy: 0.6655 - val_loss: 0.9599
# Epoch 28/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.6133 - loss: 1.1031 - val_accuracy: 0.6587 - val_loss: 0.9663
# Epoch 29/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.6155 - loss: 1.0910 - val_accuracy: 0.6645 - val_loss: 0.9646
# Epoch 30/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.6194 - loss: 1.0924 - val_accuracy: 0.6663 - val_loss: 0.9567
# Epoch 31/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.6194 - loss: 1.0827 - val_accuracy: 0.6683 - val_loss: 0.9606
# Epoch 32/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - accuracy: 0.6232 - loss: 1.0736 - val_accuracy: 0.6695 - val_loss: 0.9523
# Epoch 33/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.6192 - loss: 1.0811 - val_accuracy: 0.6650 - val_loss: 0.9571
# Epoch 34/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6257 - loss: 1.0725 - val_accuracy: 0.6695 - val_loss: 0.9630
# Epoch 35/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.6211 - loss: 1.0748 - val_accuracy: 0.6693 - val_loss: 0.9572
# Epoch 36/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - accuracy: 0.6204 - loss: 1.0760 - val_accuracy: 0.6700 - val_loss: 0.9517
# Epoch 37/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.6224 - loss: 1.0800 - val_accuracy: 0.6659 - val_loss: 0.9588
# Epoch 38/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - accuracy: 0.6264 - loss: 1.0661 - val_accuracy: 0.6707 - val_loss: 0.9461
# Epoch 39/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.6236 - loss: 1.0625 - val_accuracy: 0.6685 - val_loss: 0.9596
# Epoch 40/40
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.6245 - loss: 1.0604 - val_accuracy: 0.6691 - val_loss: 0.9513

# %% [markdown]
# **Plot training and validation curves**

# %%
import matplotlib.pyplot as plt
# Assuming 'history' is the return value from model.fit()
history_dict = history.history

# Extracting loss and accuracy history
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']
train_accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# Plotting training and validation loss
plt.figure(figsize=(14, 5))

# Training and validation loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Training and validation accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()  # Adjusts the plots to ensure they don't overlap
plt.show()

# %%
def print_best_val_loss_and_accuracy(history):
    history_dict = history.history

    # Find the index of the best validation loss
    best_val_loss_index = np.argmin(history_dict['val_loss'])

    # Retrieve the best validation loss
    best_val_loss = history_dict['val_loss'][best_val_loss_index]

    # Retrieve the validation accuracy corresponding to the best validation loss
    best_val_accuracy = history_dict['val_accuracy'][best_val_loss_index]

    print(f"Best Validation Loss: {best_val_loss}")
    print(f"Validation Accuracy at Best Loss: {best_val_accuracy}")

# %%
print_best_val_loss_and_accuracy(history)
# Out:
# Best Validation Loss: 0.9460639357566833
# Validation Accuracy at Best Loss: 0.6707000136375427

# %%
# Load the model with custom_objects
best_model = keras.models.load_model("resnet50.keras",
                                      custom_objects={'preprocess_input': tf.keras.applications.resnet50.preprocess_input},
                                      safe_mode=False)

test_loss, test_acc = best_model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.6654 - loss: 0.9519
# Test accuracy: 0.6654000282287598

# %% [markdown]
# **Fine-tuning a pre-trained ResNet50**
#
# We we not able to beat a from-scratch approach using the frozen ResNet50. Let's unfreeze the last layer to see if it helps.

# %%
base_model = keras.applications.ResNet50(include_top=False,
                                         weights='imagenet',
                                         input_shape=(32, 32, 3))
base_model.trainable = False
# To unfreeze the last layer, we set its 'trainable' attribute to True
base_model.layers[-1].trainable = True

# Define the input tensor for your model
input_tensor = Input(shape=(32, 32, 3))

# Apply data augmentation to the inputs
x = data_augmentation(input_tensor)

# Apply the preprocess_input function
x = Lambda(preprocess_input)(x)

# Add custom layers on top of the base model
x = base_model(x)
x = GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
predictions = Dense(10, activation='softmax')(x)

# Create the final model
model = Model(inputs=input_tensor, outputs=predictions)

# %%
model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="resnet50_finetune.keras",
        save_best_only=True,
        monitor="val_loss")
]

# %%
history = model.fit(x_train, y_train,
                    epochs=150,
                    batch_size=256,
                    validation_split=0.2,  # Use 20% of the data for validation
                    callbacks=callbacks,  # Include the callbacks in training
                    verbose=1)
# Out:
# Epoch 1/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 61ms/step - accuracy: 0.4162 - loss: 1.8103 - val_accuracy: 0.5891 - val_loss: 1.1797
# Epoch 2/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - accuracy: 0.5039 - loss: 1.4251 - val_accuracy: 0.6201 - val_loss: 1.1121
# Epoch 3/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - accuracy: 0.5243 - loss: 1.3573 - val_accuracy: 0.6204 - val_loss: 1.0834
# Epoch 4/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - accuracy: 0.5364 - loss: 1.3117 - val_accuracy: 0.6290 - val_loss: 1.0616
# Epoch 5/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - accuracy: 0.5515 - loss: 1.2817 - val_accuracy: 0.6397 - val_loss: 1.0310
# Epoch 6/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - accuracy: 0.5559 - loss: 1.2547 - val_accuracy: 0.6453 - val_loss: 1.0261
# Epoch 7/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - accuracy: 0.5644 - loss: 1.2378 - val_accuracy: 0.6476 - val_loss: 1.0174
# Epoch 8/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - accuracy: 0.5738 - loss: 1.2134 - val_accuracy: 0.6481 - val_loss: 1.0079
# Epoch 9/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - accuracy: 0
150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.6619 - loss: 0.9530 - val_accuracy: 0.6801 - val_loss: 0.9508
# Epoch 135/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6629 - loss: 0.9497 - val_accuracy: 0.6778 - val_loss: 0.9443
# Epoch 136/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.6635 - loss: 0.9501 - val_accuracy: 0.6760 - val_loss: 0.9579
# Epoch 137/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6618 - loss: 0.9573 - val_accuracy: 0.6751 - val_loss: 0.9631
# Epoch 138/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - accuracy: 0.6619 - loss: 0.9519 - val_accuracy: 0.6746 - val_loss: 0.9613
# Epoch 139/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6575 - loss: 0.9614 - val_accuracy: 0.6752 - val_loss: 0.9556
# Epoch 140/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.6619 - loss: 0.9577 - val_accuracy: 0.6722 - val_loss: 0.9736
# Epoch 141/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6630 - loss: 0.9504 - val_accuracy: 0.6755 - val_loss: 0.9654
# Epoch 142/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.6630 - loss: 0.9526 - val_accuracy: 0.6752 - val_loss: 0.9610
# Epoch 143/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6641 - loss: 0.9530 - val_accuracy: 0.6801 - val_loss: 0.9610
# Epoch 144/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.6654 - loss: 0.9539 - val_accuracy: 0.6794 - val_loss: 0.9593
# Epoch 145/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.6620 - loss: 0.9566 - val_accuracy: 0.6748 - val_loss: 0.9517
# Epoch 146/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.6657 - loss: 0.9495 - val_accuracy: 0.6805 - val_loss: 0.9568
# Epoch 147/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.6650 - loss: 0.9496 - val_accuracy: 0.6779 - val_loss: 0.9662
# Epoch 148/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6675 - loss: 0.9477 - val_accuracy: 0.6776 - val_loss: 0.9559
# Epoch 149/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.6650 - loss: 0.9510 - val_accuracy: 0.6786 - val_loss: 0.9653
# Epoch 150/150
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.6644 - loss: 0.9540 - val_accuracy: 0.6783 - val_loss: 0.9542

# %%
print_best_val_loss_and_accuracy(history)
# Out:
# Best Validation Loss: 0.9343456029891968
# Validation Accuracy at Best Loss: 0.6766999959945679

# %%
# Assuming 'history' is the return value from model.fit()
history_dict = history.history

# Extracting loss and accuracy history
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']
train_accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# Plotting training and validation loss
plt.figure(figsize=(14, 5))

# Training and validation loss plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Training and validation accuracy plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()  # Adjusts the plots to ensure they don't overlap
plt.show()

# %%
# Load the model with custom_objects
best_model = keras.models.load_model("resnet50_finetune.keras",
                                      custom_objects={'preprocess_input': tf.keras.applications.resnet50.preprocess_input},
                                      safe_mode=False)

test_loss, test_acc = best_model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.6700 - loss: 0.9464
# Test accuracy: 0.6700000166893005

# %% [markdown]
# **Conclusion**
#
# We were not able to beat the from-scratch approach despite having adjusted the weights in the last layer and running for twice the number of epochs. What are the ways forward? Here are a couple of suggestions:
#
# *   **Unfreeze more layers**. Fine-tuning more layers may allow the pretrained network to better adapt to the specifics of the dataset.
#
# *   **Advanced Data Augmentation**: Explore more sophisticated data augmentation techniques. Sometimes, introducing variations in the augmentation can help the model generalize better.
#
# *   **Try a different pre-trained model**. The problem might be ResNet50 itself. Keras includes many different pre-trained models. See here for a [list](https://keras.io/api/applications/).
